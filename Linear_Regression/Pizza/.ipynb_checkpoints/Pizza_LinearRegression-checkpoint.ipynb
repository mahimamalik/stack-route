# %% [markdown]
# ## Pizza DataSet

# %%
#import statements

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas.tools.plotting import scatter_matrix
import seaborn as sns
from sklearn import linear_model

# %% [markdown]
# ## Reading the data

# %%
pizza = pd.read_csv("Ex06_Pizzademand_Regreesion.csv")
pizza
# Out:
#     PizzaPrice  BurgerPrice  RoomTemperature  DeliveryMode     Income  \
# 0    11.716233     9.716233        24.937096             2  21.772162
# 1     8.695689     6.695689        24.772566             1  43.172762
# 2     7.056686     5.056686        25.033494             2  18.661751
# 3    12.499111    10.499111        24.978631             1  92.107600
# 4     8.208723     6.208723        24.996846             2  51.482776
# 5    12.002101    10.002101        24.930392             1  64.361716
# 6     8.546705     6.546705        25.096842             1  46.600874
# 7     7.711771     5.711771        25.239635             1  66.090001
# 8     5.448403     3.448403        25.147612             1  23.097988
# 9     8.808416     6.808416        24.953281             1  48.107678
# 10    1.223003    -0.776997        24.941055             2  39.564492
# 11   11.536461     9.536461        24.901248             2  36.260025
# 12   10.706273     8.706273        25.016071             2  56.597523
# 13    9.880174     7.880174        24.830438             1  28.994956
# 14    8.752853     6.752853        24.984566             2  25.535755
# 15    9.657947     7.657947        24.943576             2  28.935639
# 16   10.852263     8.852263        24.811352             1  56.450701
# 17    5.856543     3.856543        24.964816             2  48.459124
# 18   13.675117    11.675117        25.030425             1  97.144516
# 19   12.185952    10.185952        24.867871             1  78.307117
# 20    8.340169     6.340169        24.854277             2  88.299050
# 21    9.124910     7.124910        25.114750             2  57.265555
# 22   12.393519    10.393519        25.121254             2  32.393324
# 23    4.273301     2.273301        25.015859             2  20.592647
# 24    5.892033     3.892033        24.823758             2  20.970274
# 25   10.601820     8.601820        25.026017             2  10.488050
# 26    7.720145     5.720145        25.016208             2  91.000000
# 27   11.790139     9.790139        24.848153             2  55.731061
# 28   -0.058743    -2.058743        24.981258             2  57.990971
# 29    5.282773     3.282773        25.218333             1  43.895123
# ..         ...          ...              ...           ...        ...
# 70   11.403911     9.403911        24.927563             1  42.646310
# 71    7.289431     5.289431        25.096529             1  71.402780
# 72    6.267234     4.267234        24.991389             2  35.682095
# 73    9.107581     7.107581        25.039801             1  45.729697
# 74    6.287639     4.287639        24.956903             2  39.848196
# 75    9.391228     7.391228        24.997033             2  83.265252
# 76    2.315065     0.315065        25.035787             1  15.886032
# 77    8.611302     6.611302        24.962813             1  85.776772
# 78    7.757068     5.757068        24.928866             2  77.664832
# 79    3.470991     1.470991        25.054836             2  82.028408
# 80    7.965484     5.965484        25.059993             2  50.459719
# 81    4.551174     2.551174        25.169556             2  66.344564
# 82    8.349198     6.349198        25.077081             2  84.873987
# 83    9.041913     7.041913        25.006658             1  57.213692
# 84    9.640799     7.640799        24.860340             2  75.549649
# 85    6.445769     4.445769        25.053080             1  41.764393
# 86   11.885422     9.885422        24.933979             1  94.000000
# 87   10.859449     8.859449        25.058468             2  79.485076
# 88    7.709914     5.709914        25.209865             2  77.006809
# 89    9.182443     7.182443        24.911357             1  92.782186
# 90   12.611691    10.611691        24.999277             2  35.349440
# 91    9.108147     7.108147        25.009915             2  13.850653
# 92    4.617136     2.617136        24.892857             1  29.616967
# 93    7.411542     5.411542        24.923384             2  53.110713
# 94    7.206652     5.206652        25.039169             2  27.600181
# 95    6.829640     4.829640        24.950304             1  37.020173
# 96    8.052243     6.052243        25.032996             2  35.956006
# 97    7.126427     5.126427        25.081704             1  39.756595
# 98   11.497405     9.497405        25.030255             1  97.000000
# 99   15.296247    13.296247        24.984838             2  62.690741
#
#     softdrinkPrice  Location   PizzaDemand
# 0        20.251733         2  15383.265370
# 1        14.877143         1  16036.037969
# 2        16.041785         1  15317.391311
# 3        22.401484         1  17327.343321
# 4        27.352832         1  16077.301577
# 5        21.492615         2  16559.697374
# 6        32.191434         1  15870.785423
# 7        21.015184         1  16576.735275
# 8        13.417359         2  15466.477130
# 9        28.615862         1  15969.058617
# 10       42.567035         1  15452.294188
# 11       24.600436         2  15722.179091
# 12       25.072211         1  16277.007674
# 13       40.499916         2  15265.221648
# 14       38.944507         2  15181.602366
# 15       34.330840         2  15354.050629
# 16       30.771895         2  16188.614667
# 17       38.217478         1  15808.245959
# 18       39.666145         2  17220.223688
# 19       32.231373         1  16790.673573
# 20       41.071511         2  16903.443194
# 21       37.812621         1  16090.280177
# 22       21.635584         1  15666.113005
# 23       32.921414         2  15093.236678
# 24       43.123104         1  14965.398266
# 25       30.787177         1  14899.253952
# 26       45.930409         2  16900.573170
# 27       22.833185         2  16296.128638
# 28       43.217584         1  15946.990094
# 29       55.652873         1  15413.616366
# ..             ...       ...           ...
# 70       49.149109         2  15531.491464
# 71       26.609814         1  16637.706477
# 72       22.619743         2  15688.402322
# 73       23.858286         1  15976.592791
# 74       33.861856         2  15636.430613
# 75       16.470791         2  17140.948747
# 76       39.829075         2  14840.256545
# 77       50.565423         2  16692.750142
# 78       41.589776         2  16592.656181
# 79       26.058688         2  16909.165145
# 80       30.385291         1  16001.023196
# 81       28.482536         2  16443.308725
# 82       36.237710         1  16880.136239
# 83       22.609829         1  16316.266556
# 84       27.650863         2  16759.289199
# 85       28.541127         1  15771.243997
# 86       30.201774         1  17257.864799
# 87       33.069264         2  16799.344531
# 88       21.600233         2  16873.628702
# 89       35.287176         1  17123.546797
# 90       38.203881         1  15502.421699
# 91       32.353379         2  14956.504657
# 92       43.115394         2  15196.009570
# 93      -10.752252         1  16686.988632
# 94       38.425089         2  15233.477175
# 95       39.464020         2  15477.953169
# 96       41.980633         2  15421.492311
# 97       24.333001         1  15784.297695
# 98       13.566898         1  17587.812943
# 99       26.378772         1  16469.368454
#
# [100 rows x 8 columns]

# %% [markdown]
# ## Scatter Plots

# %%
plt.scatter(pizza['PizzaPrice'], pizza['PizzaDemand'])
plt.show()

# %%
plt.scatter(pizza['BurgerPrice'], pizza['PizzaDemand'])
plt.show()

# %%
plt.scatter(pizza['RoomTemperature'], pizza['PizzaDemand'])
plt.show()

# %%
plt.scatter(pizza['DeliveryMode'], pizza['PizzaDemand'])
plt.show()

# %%
plt.scatter(pizza['Income'], pizza['PizzaDemand'])
plt.show()

# %%
plt.scatter(pizza['softdrinkPrice'], pizza['PizzaDemand'])
plt.show()

# %%
plt.scatter(pizza['Location'], pizza['PizzaDemand'])
plt.show()

# %%
scatter_matrix(pizza, alpha=0.2, figsize=(15, 10), diagonal='kde')
plt.show()

# %% [markdown]
# ## Feature Corelation Matrix

# %%
pizza_corr = pizza.corr()
sns.heatmap(pizza_corr, vmax=.8, square=True)
plt.show()

# %% [markdown]
# ## Training and Test Datasets

# %% [markdown]
# Training set

# %%
train_pizza = pizza[:int(0.8*len(pizza))]
x_train = train_pizza.drop('PizzaDemand', axis = 1)
y_train = train_pizza[['PizzaDemand']]

# %% [markdown]
# Test set

# %%
test_pizza = pizza[int(0.8*len(pizza)):]
x_test = test_pizza.drop('PizzaDemand', axis = 1)
y_test = np.array(test_pizza[['PizzaDemand']])

# %% [markdown]
# ## Normalising the Dataset

# %%
x_train_std = np.array((x_train - x_train.mean())/x_train.std())
y_train_std = np.array((y_train - y_train.mean())/y_train.std())
x_test_std = np.array((x_test - x_test.mean())/x_test.std())

# %% [markdown]
# ## Linear Regression Model

# %%
linear_reg = linear_model.LinearRegression(normalize=True)
linear_reg = linear_reg.fit(x_train_std, y_train_std)

# %%
linear_reg.coef_
# Out:
# array([[ -8.10397464e+08,   8.10397464e+08,   4.15774881e-07,
#           1.76369022e-05,   9.73786416e-01,  -2.15765932e-01,
#           1.95866852e-05]])

# %%
linear_coeff = linear_reg.coef_

# %%
linear_intercept = linear_reg.intercept_

# %%
linear_predicted = linear_reg.predict(x_test_std)

# %%
linear_predicted = (linear_predicted * y_test.std()) + y_test.mean()

# %%
plt.scatter(linear_predicted, y_test)
plt.show()

# %%
linear_residuals = linear_predicted - y_test
linear_residuals_df = pd.DataFrame(linear_residuals)

# %%
linear_residuals_df.plot(kind = 'hist')
plt.show()

# %%
linear_residuals_df.plot(kind = 'box')
plt.show()

# %% [markdown]
# ## Linear Regression Model - Lasso

# %%
#alphas = np.linspace(0.00001,0.3,100000)*0.5
alphas = np.linspace(0.00001,1,1000)*0.5

# %%
lasso_model = linear_model.Lasso(max_iter=10000, normalize=True)
lasso_coeff = []

for a in alphas:
    lasso_model.set_params(alpha = a)
    lasso_model.fit(x_train_std, y_train_std)
    lasso_coeff.append(lasso_model.coef_)

# %%
ax = plt.gca()
ax.plot(2*alphas, lasso_coeff)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
plt.show()

# %%
y_train_std = y_train_std.reshape(80,)
lassocv = linear_model.LassoCV(alphas = alphas, cv=10, max_iter=100000, normalize=True)
lassocv.fit(x_train_std, y_train_std)
# Out:
# LassoCV(alphas=array([  5.00000e-06,   5.05495e-04, ...,   4.99500e-01,   5.00000e-01]),
#     copy_X=True, cv=10, eps=0.001, fit_intercept=True, max_iter=100000,
#     n_alphas=100, n_jobs=1, normalize=True, positive=False,
#     precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#     verbose=False)

# %%
lasso_model.set_params(alpha=lassocv.alpha_)
lasso_model.fit(x_train_std, y_train_std)
# Out:
# Lasso(alpha=5.0000000000000004e-06, copy_X=True, fit_intercept=True,
#    max_iter=10000, normalize=True, positive=False, precompute=False,
#    random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
lasso_predicted = lasso_model.predict(x_test_std)
lasso_predicted = lasso_predicted.reshape(20,1)
lasso_predicted = (lasso_predicted * y_test.std()) + y_test.mean()

# %%
plt.scatter(lasso_predicted, y_test)
plt.show()

# %%
lasso_residuals = lasso_predicted - y_test
lasso_residuals_df = pd.DataFrame(lasso_residuals)

# %%
lasso_residuals_df.plot(kind = 'hist')
plt.show()

# %%
lasso_residuals_df.plot(kind = 'box')
plt.show()

# %% [markdown]
# ## Linear Regression Model - Ridge Regression

# %%
alphas = np.linspace(0.001,50,1000)*0.5

# %%
ridge_model = linear_model.Ridge(normalize = True)
ridge_coeff = []
for a in alphas:
    ridge_model.set_params(alpha = a)
    ridge_model.fit(x_train_std, y_train_std)
    ridge_coeff.append(ridge_model.coef_)

# %%
ax = plt.gca()
ax.plot(alphas*2, ridge_coeff)
plt.xlabel('alpha')
plt.ylabel('weights')
plt.show()

# %%
y_train_std = y_train_std.reshape(80,)
ridgecv = linear_model.RidgeCV(alphas = alphas, normalize=True)
ridgecv.fit(x_train_std, y_train_std)
# Out:
# RidgeCV(alphas=array([  5.00000e-04,   2.55245e-02, ...,   2.49750e+01,   2.50000e+01]),
#     cv=None, fit_intercept=True, gcv_mode=None, normalize=True,
#     scoring=None, store_cv_values=False)

# %%
ridge_model.set_params(alpha = ridgecv.alpha_)
ridge_model.fit(x_train_std, y_train_std)
# Out:
# Ridge(alpha=0.00050000000000000001, copy_X=True, fit_intercept=True,
#    max_iter=None, normalize=True, random_state=None, solver='auto',
#    tol=0.001)

# %%
ridge_predicted = ridge_model.predict(x_test_std)
ridge_predicted = ridge_predicted.reshape(20,1)
ridge_predicted = (ridge_predicted * y_test.std()) + y_test.mean()

# %%
plt.scatter(ridge_predicted, y_test)
plt.show()

# %%
ridge_residuals = ridge_predicted - y_test
ridge_residuals_df = pd.DataFrame(ridge_residuals)

# %%
ridge_residuals_df.plot(kind = 'hist')
plt.show()

# %%
ridge_residuals_df.plot(kind = 'box')
plt.show()
