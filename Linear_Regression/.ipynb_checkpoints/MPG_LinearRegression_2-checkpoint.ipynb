# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from pandas.tools.plotting import scatter_matrix

# %%
mpg_data = pd.read_csv('Ex04_Mpg_Regression.csv')

# %%
mpg_data.horsepower = mpg_data.horsepower.str.replace('?','0.0').astype(float)

# %%
mpg_data.carname = pd.Categorical(mpg_data['carname']).codes

# %%
mpg_df = (mpg_data - mpg_data.mean())/mpg_data.std()

# %%
#mpg_data.displacement

# %%
mpg_data = mpg_data.apply(lambda x: 1./(x+0.0001))

# %%
#mpg_data

# %%
plt.scatter(mpg_data['displacement'], mpg_data['mpg'])
plt.show()

# %%
# import math
# mpg_data['horsepower'] = mpg_data['horsepower'].apply(lambda x: math.exp(x))

# %%
mpg_data['horsepower'].mean()
# Out:
# 151.14410778661673

# %%
plt.scatter(mpg_data['horsepower'], mpg_data['mpg'])
plt.show()

# %%
scatter_matrix(mpg_df, alpha=0.2, figsize=(15, 10), diagonal='kde')
plt.show()
